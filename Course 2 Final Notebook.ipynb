# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ## __Tracy__
# <br>
# I'm desired to work as Data Scientist in medical field

# %% [markdown]
# *Through learning of Data science I'm urged to involve myself in Health care industry. In a way that more and more people can predict diseases in earliest stage and accurate treatments to be carry out with the help of data science. Effective and improving Health care system definitely is life changing career move!*

# %% [markdown]
# ### Swap the values of a & b

# %%
a = 1 
b = 2 

# Swap the values 
a, b = b, a 

# print new value of a 
print("a:", a) 

# print new value of b 
print("b:", b)
# Out:
# a: 2
# b: 1

# %% [markdown]
# Highlighting:
# <br>
# `Data science`
#
# <br>
#
# Blockquote: </p>
# <blockquote>This is a blockquote</p>
# <blockquote>This is a blockquote</p>
# <blockquote>This is a blockquote
# </blockquote>
# </blockquote>
# </blockquote>
#
# Numbered list:
#    1. a
#    2. b
#    3. c
#
# Bulleted list:
#    - a
#    - b
#    - c
#
# Strikethrough: </p>
# ~~strike~~
#
# <br>
#
# Code:
# ```Python
# import csv
# ```
# <br>
#
# Table:
# | Name | Age | Gender |
# | --- | --- | --- |
# | Kyle | 20 | Male |
# | Mery | 22 | Female |
#
# <br>
#
# Hyperlink: </p>
# https://www.coursera.org/professional-certificates/ibm-data-science </p>
# Link:  </p>
# [Data Science](https://www.coursera.org/professional-certificates/ibm-data-science) </p>
# ![Coursera](https://1000logos.net/wp-content/uploads/2022/06/Coursera-Logo.png)
